# %% [markdown]
# # Relevant Imports

# %%
# Cell 1: Relevant Imports
# We need the same imports as in the RoBERTa_base.ipynb for sentiment annotation
import pandas as pd
import numpy as np
import torch
import re
import nltk
from nltk.corpus import stopwords
from transformers import AutoTokenizer, AutoModelForSequenceClassification, TextClassificationPipeline
nltk.download('stopwords', quiet=True)  # Ensure stopwords are downloaded
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/opt/anaconda3/envs/thesis/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#     self._run_once()
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/asyncio/base_events.py", line 1905, in _run_once
#     handle._run()
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3024, in run_cell
#     result = self._run_cell(
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3079, in _run_cell
#     result = runner(coro)
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3284, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3466, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/pd/35sqmnx90k31hxsfkmzt115m000cd0/T/ipykernel_70080/1368807360.py", line 9, in <module>
#     from transformers import AutoTokenizer, AutoModelForSequenceClassification, TextClassificationPipeline
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/transformers/utils/import_utils.py", line 1805, in __getattr__
#     module = self._get_module(self._class_to_module[name])
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/transformers/utils/import_utils.py", line 1817, in _get_module
#     return importlib.import_module("." + module_name, self.__name__)
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/transformers/pipelines/__init__.py", line 26, in <module>
#     from ..image_processing_utils import BaseImageProcessor
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/transformers/image_processing_utils.py", line 21, in <module>
#     from .image_transforms import center_crop, normalize, rescale
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/transformers/image_transforms.py", line 22, in <module>
#     from .image_utils import (
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/transformers/image_utils.py", line 59, in <module>
#     from torchvision.transforms import InterpolationMode
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/torchvision/__init__.py", line 10, in <module>
#     from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils  # usort:skip
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/torchvision/models/__init__.py", line 2, in <module>
#     from .convnext import *
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/torchvision/models/convnext.py", line 8, in <module>
#     from ..ops.misc import Conv2dNormActivation, Permute
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/torchvision/ops/__init__.py", line 1, in <module>
#     from ._register_onnx_ops import _register_custom_op
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/torchvision/ops/_register_onnx_ops.py", line 5, in <module>
#     from torch.onnx import symbolic_opset11 as opset11
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/torch/onnx/__init__.py", line 62, in <module>
#     from ._internal.onnxruntime import (
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/torch/onnx/_internal/onnxruntime.py", line 37, in <module>
#     import onnxruntime  # type: ignore[import]
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/onnxruntime/__init__.py", line 23, in <module>
#     from onnxruntime.capi._pybind_state import ExecutionMode  # noqa: F401
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/onnxruntime/capi/_pybind_state.py", line 32, in <module>
#     from .onnxruntime_pybind11_state import *  # noqa
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ImportError: numpy.core.multiarray failed to import
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in function __import__> returned a result with an error set
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/opt/anaconda3/envs/thesis/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#     self._run_once()
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/asyncio/base_events.py", line 1905, in _run_once
#     handle._run()
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3024, in run_cell
#     result = self._run_cell(
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3079, in _run_cell
#     result = runner(coro)
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3284, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3466, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/pd/35sqmnx90k31hxsfkmzt115m000cd0/T/ipykernel_70080/1368807360.py", line 9, in <module>
#     from transformers import AutoTokenizer, AutoModelForSequenceClassification, TextClassificationPipeline
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/transformers/utils/import_utils.py", line 1805, in __getattr__
#     module = self._get_module(self._class_to_module[name])
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/transformers/utils/import_utils.py", line 1817, in _get_module
#     return importlib.import_module("." + module_name, self.__name__)
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/transformers/pipelines/__init__.py", line 26, in <module>
#     from ..image_processing_utils import BaseImageProcessor
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/transformers/image_processing_utils.py", line 21, in <module>
#     from .image_transforms import center_crop, normalize, rescale
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/transformers/image_transforms.py", line 50, in <module>
#     import tensorflow as tf
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/tensorflow/__init__.py", line 49, in <module>
#     from tensorflow._api.v2 import __internal__
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/tensorflow/_api/v2/__internal__/__init__.py", line 8, in <module>
#     from tensorflow._api.v2.__internal__ import autograph
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/tensorflow/_api/v2/__internal__/autograph/__init__.py", line 8, in <module>
#     from tensorflow.python.autograph.core.ag_ctx import control_status_ctx # line: 34
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/tensorflow/python/autograph/core/ag_ctx.py", line 21, in <module>
#     from tensorflow.python.autograph.utils import ag_logging
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/tensorflow/python/autograph/utils/__init__.py", line 17, in <module>
#     from tensorflow.python.autograph.utils.context_managers import control_dependency_on_returns
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/tensorflow/python/autograph/utils/context_managers.py", line 19, in <module>
#     from tensorflow.python.framework import ops
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/tensorflow/python/framework/ops.py", line 62, in <module>
#     from tensorflow.python.framework import tensor as tensor_lib
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/tensorflow/python/framework/tensor.py", line 35, in <module>
#     from tensorflow.python.framework import tensor_util
#   File "/opt/anaconda3/envs/thesis/lib/python3.9/site-packages/tensorflow/python/framework/tensor_util.py", line 39, in <module>
#     from tensorflow.python.framework import fast_tensor_util
# True
